# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"D:\Downloads\homeprices_banglore.csv")
df.head()
# Out:
#    area  bedrooms   price
# 0  1056         2   39.07
# 1  2600         4  120.00
# 2  1440         3   62.00
# 3  1521         3   75.00
# 4  1200         2   51.00

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaled_X = scaler.fit_transform(df.drop("price", axis=1))
scaled_X
# Out:
# array([[0.08827586, 0.25      ],
#        [0.62068966, 0.75      ],
#        [0.22068966, 0.5       ],
#        [0.24862069, 0.5       ],
#        [0.13793103, 0.25      ],
#        [0.12758621, 0.25      ],
#        [0.6662069 , 0.75      ],
#        [0.86206897, 0.75      ],
#        [0.17586207, 0.5       ],
#        [1.        , 1.        ],
#        [0.34482759, 0.5       ],
#        [0.68448276, 0.75      ],
#        [0.06896552, 0.25      ],
#        [0.10344828, 0.25      ],
#        [0.5       , 0.5       ],
#        [0.12931034, 0.25      ],
#        [0.13103448, 0.5       ],
#        [0.25517241, 0.5       ],
#        [0.67931034, 0.5       ],
#        [0.        , 0.        ]])

# %%
scaled_y = scaler.fit_transform(df.price.values.reshape(df.shape[0],1))
scaled_y
# Out:
# array([[0.05237037],
#        [0.65185185],
#        [0.22222222],
#        [0.31851852],
#        [0.14074074],
#        [0.04444444],
#        [0.76296296],
#        [0.91111111],
#        [0.13333333],
#        [1.        ],
#        [0.37037037],
#        [0.8       ],
#        [0.04444444],
#        [0.05925926],
#        [0.51111111],
#        [0.07407407],
#        [0.11851852],
#        [0.20740741],
#        [0.51851852],
#        [0.        ]])

# %% [markdown]
# **Implementing the batch gradient descent on this dataset to finding out the weights**

# %%
def batch_gradient_descent(X, y_true, epochs, learning rate=0.01):
